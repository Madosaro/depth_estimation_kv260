# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# <h1><b>TRAINING</b></h1>
# <p>training.ipynb</p>

# %%
import os

DATASET_PATH = "/workspace/Dataset/nyudepthv2"

try:
    import kagglehub
    dataset_path = kagglehub.dataset_download("awsaf49/nyuv2-official-split-dataset")
    print("Kagglehub detected. Using downloaded path:", dataset_path)
except ImportError:
    dataset_path = DATASET_PATH
    print("Kagglehub not found (Vitis AI Docker environment). Falling back to manual path:", dataset_path)
assert os.path.exists(dataset_path), f"CRITICAL: The dataset path '{dataset_path}' does not exist!"
# Out:
# Kagglehub detected. Using downloaded path: /home/mado/.cache/kagglehub/datasets/awsaf49/nyuv2-official-split-dataset/versions/1

# %%
from src.train import train

MODEL_NAME = "MDE_UNET"

train(
    dataset_path=dataset_path,
    epochs=20,
    num_imgs=50000,
    model_name=MODEL_NAME,
    resume_epoch=None,
    checkpoint_every=1
)
# Out:
# Starting training...
#
# 	|- Files found : 47584 pairs rgb/depth
# 	|- Datasets :
# 	|	|- Train : 38067 pairs (80.0%)
# 	|	|- Validation : 9517 pairs (20.0%)
# 	|- Device :  cuda:0
# 	|- Model :
# 	|	|- Loading checkpoint from './models/MDE_UNET/MDE_UNET.pth'...
# 	|	|- Model state restored successfully (epoch 11).
# 	|	|- Loading training history from './models/MDE_UNET/MDE_UNET_history.json'.
# 	|- Epochs : 20
# Training:   0%|          | 0/20 [00:00<?, ?epoch/s]
# 	|	|- Snapshot saved: './models/MDE_UNET/checkpoints/MDE_UNET_epoch12.pth'
# 	|	|- Snapshot saved: './models/MDE_UNET/checkpoints/MDE_UNET_epoch13.pth'
# 	|	|- Snapshot saved: './models/MDE_UNET/checkpoints/MDE_UNET_epoch14.pth'
# 	|	|- Snapshot saved: './models/MDE_UNET/checkpoints/MDE_UNET_epoch15.pth'
# 	|	|- Snapshot saved: './models/MDE_UNET/checkpoints/MDE_UNET_epoch16.pth'
# 	|	|- Snapshot saved: './models/MDE_UNET/checkpoints/MDE_UNET_epoch17.pth'
# 	|	|- Snapshot saved: './models/MDE_UNET/checkpoints/MDE_UNET_epoch18.pth'
# 	|	|- Snapshot saved: './models/MDE_UNET/checkpoints/MDE_UNET_epoch19.pth'
# 	|	|- Snapshot saved: './models/MDE_UNET/checkpoints/MDE_UNET_epoch20.pth'
# 	|	|- Snapshot saved: './models/MDE_UNET/checkpoints/MDE_UNET_epoch21.pth'
# 	|	|- Snapshot saved: './models/MDE_UNET/checkpoints/MDE_UNET_epoch22.pth'
# 	|	|- Snapshot saved: './models/MDE_UNET/checkpoints/MDE_UNET_epoch23.pth'
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 5
#       1 from src.train import train
#       3 MODEL_NAME = "MDE_UNET"
# ----> 5 train(
#       6     dataset_path=dataset_path,
#       7     epochs=20,
#       8     num_imgs=50000,
#       9     model_name=MODEL_NAME,
#      10     resume_epoch=None,
#      11     checkpoint_every=1
#      12 )
#
# File ~/stage/depth_estimation_kv260/src/train.py:189, in train(dataset_path, epochs, num_imgs, model_name, resume_epoch, checkpoint_every)
#     186 start_time = time.time()
#     188 #--- start a training session and get training report data
# --> 189 loss_t, l1_t, l2_t, l3_t, l4_t = train_model(
#     190     model, train_dataloader, optimizer,
#     191     loss_function, device, w1, w2, w3, w4
#     192 )
#     194 #--- switch to evaluation mode and evaluate training perfomance on validation data
#     195 with torch.no_grad():
#
# File ~/stage/depth_estimation_kv260/src/train.py:35, in train_model(model, train_dataloader, optimizer, loss_function, device, w1, w2, w3, w4)
#      32 loss, l1, l2, l3, l4 = loss_function(outputs, labels, w1, w2, w3, w4, True)
#      34 loss.backward()
# ---> 35 optimizer.step()
#      37 losses.append(loss.detach().item())
#      38 l1_list.append(l1.detach().item())
#
# File ~/.conda/envs/depth_estimation_kv260/lib/python3.11/site-packages/torch/optim/optimizer.py:391, in Optimizer.profile_hook_step.<locals>.wrapper(*args, **kwargs)
#     386         else:
#     387             raise RuntimeError(
#     388                 f"{func} must return None or a tuple of (new_args, new_kwargs), but got {result}."
#     389             )
# --> 391 out = func(*args, **kwargs)
#     392 self._optimizer_step_code()
#     394 # call optimizer step post hooks
#
# File ~/.conda/envs/depth_estimation_kv260/lib/python3.11/site-packages/torch/optim/optimizer.py:76, in _use_grad_for_differentiable.<locals>._use_grad(self, *args, **kwargs)
#      74     torch.set_grad_enabled(self.defaults['differentiable'])
#      75     torch._dynamo.graph_break()
# ---> 76     ret = func(self, *args, **kwargs)
#      77 finally:
#      78     torch._dynamo.graph_break()
#
# File ~/.conda/envs/depth_estimation_kv260/lib/python3.11/site-packages/torch/optim/adamw.py:188, in AdamW.step(self, closure)
#     175     beta1, beta2 = group["betas"]
#     177     has_complex = self._init_group(
#     178         group,
#     179         params_with_grad,
#    (...)
#     185         state_steps,
#     186     )
# --> 188     adamw(
#     189         params_with_grad,
#     190         grads,
#     191         exp_avgs,
#     192         exp_avg_sqs,
#     193         max_exp_avg_sqs,
#     194         state_steps,
#     195         amsgrad=amsgrad,
#     196         beta1=beta1,
#     197         beta2=beta2,
#     198         lr=group["lr"],
#     199         weight_decay=group["weight_decay"],
#     200         eps=group["eps"],
#     201         maximize=group["maximize"],
#     202         foreach=group["foreach"],
#     203         capturable=group["capturable"],
#     204         differentiable=group["differentiable"],
#     205         fused=group["fused"],
#     206         grad_scale=getattr(self, "grad_scale", None),
#     207         found_inf=getattr(self, "found_inf", None),
#     208         has_complex=has_complex,
#     209     )
#     211 return loss
#
# File ~/.conda/envs/depth_estimation_kv260/lib/python3.11/site-packages/torch/optim/adamw.py:340, in adamw(params, grads, exp_avgs, exp_avg_sqs, max_exp_avg_sqs, state_steps, foreach, capturable, differentiable, fused, grad_scale, found_inf, has_complex, amsgrad, beta1, beta2, lr, weight_decay, eps, maximize)
#     337 else:
#     338     func = _single_tensor_adamw
# --> 340 func(
#     341     params,
#     342     grads,
#     343     exp_avgs,
#     344     exp_avg_sqs,
#     345     max_exp_avg_sqs,
#     346     state_steps,
#     347     amsgrad=amsgrad,
#     348     beta1=beta1,
#     349     beta2=beta2,
#     350     lr=lr,
#     351     weight_decay=weight_decay,
#     352     eps=eps,
#     353     maximize=maximize,
#     354     capturable=capturable,
#     355     differentiable=differentiable,
#     356     grad_scale=grad_scale,
#     357     found_inf=found_inf,
#     358     has_complex=has_complex,
#     359 )
#
# File ~/.conda/envs/depth_estimation_kv260/lib/python3.11/site-packages/torch/optim/adamw.py:595, in _multi_tensor_adamw(params, grads, exp_avgs, exp_avg_sqs, max_exp_avg_sqs, state_steps, grad_scale, found_inf, amsgrad, beta1, beta2, lr, weight_decay, eps, maximize, capturable, differentiable, has_complex)
#     593     torch._foreach_addcdiv_(device_params, device_exp_avgs, exp_avg_sq_sqrt)
#     594 else:
# --> 595     bias_correction1 = [1 - beta1 ** _get_value(step) for step in device_state_steps]
#     596     bias_correction2 = [1 - beta2 ** _get_value(step) for step in device_state_steps]
#     598     step_size = _stack_if_compiling([(lr / bc) * -1 for bc in bias_correction1])
#
# File ~/.conda/envs/depth_estimation_kv260/lib/python3.11/site-packages/torch/optim/adamw.py:595, in <listcomp>(.0)
#     593     torch._foreach_addcdiv_(device_params, device_exp_avgs, exp_avg_sq_sqrt)
#     594 else:
# --> 595     bias_correction1 = [1 - beta1 ** _get_value(step) for step in device_state_steps]
#     596     bias_correction2 = [1 - beta2 ** _get_value(step) for step in device_state_steps]
#     598     step_size = _stack_if_compiling([(lr / bc) * -1 for bc in bias_correction1])
#
# File ~/.conda/envs/depth_estimation_kv260/lib/python3.11/site-packages/torch/optim/optimizer.py:89, in _get_value(x)
#      87     return x
#      88 else:
# ---> 89     return x.item()
#
# KeyboardInterrupt:
